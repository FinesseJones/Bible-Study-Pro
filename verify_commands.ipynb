# %%
This notebook runs the three requested commands sequentially in the application workspace.</VSCode.Cell>
<VSCode.Cell language="python">import subprocess
from pathlib import Path

workspace = Path('/Users/finessejones1/Desktop/bible-study-pro 2')
print('Workspace:', workspace)
print('Exists:', workspace.exists())</VSCode.Cell>
<VSCode.Cell language="python">print('Running step 1: npm run check')
result = subprocess.run(['npm', 'run', 'check'], cwd=workspace, capture_output=True, text=True)
print('Exit code:', result.returncode)
print(result.stdout)
print(result.stderr)</VSCode.Cell>
<VSCode.Cell language="python">print('Running step 2: npm run build')
result = subprocess.run(['npm', 'run', 'build'], cwd=workspace, capture_output=True, text=True)
print('Exit code:', result.returncode)
print(result.stdout[:2000])
print(result.stderr[:2000])</VSCode.Cell>
<VSCode.Cell language="python">print('Running step 3: npm run test')
result = subprocess.run(['npm', 'run', 'test'], cwd=workspace, capture_output=True, text=True)
print('Exit code:', result.returncode)
print(result.stdout[:2000])
print(result.stderr[:2000])
